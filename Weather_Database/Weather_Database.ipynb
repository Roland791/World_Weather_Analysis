# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
weather_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_condition = city_weather["weather"][0]["description"]   
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into weather_database list.
        weather_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Date": city_date,
                          "Current Description": city_condition})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | esperance
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | tiksi
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | airai
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | labuhan
# Processing Record 9 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 1 | karratha
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | mareeba
# Processing Record 16 of Set 1 | lohardaga
# Processing Record 17 of Set 1 | sorong
# Processing Record 18 of Set 1 | wamba
# Processing Record 19 of Set 1 | wasilla
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | dingle
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 1 | asau
# Processing Record 25 of Set 1 | sitka
# Processing Record 26 of Set 1 | murgab
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | bocaranga
# City not found. Skipping...
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | pacific grove
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | arlit
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | hualmay
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | broome
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | tigzirt
# Processing Record 39 of Set 1 | pechora
# Processing Record 40 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | praia da vitoria
# Processing Record 43 of Set 1 | bilibino
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | new norfolk
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | floro
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | manggar
# Processing Record 50 of Set 1 | mikhaylovka
# Processing Record 1 of Set 2 | mana
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | lorengau
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | aklavik
# Processing Record 6 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 2 | faanui
# Processing Record 8 of Set 2 | pisco
# Processing Record 9 of Set 2 | nosy varika
# Processing Record 10 of Set 2 | carnarvon
# Processing Record 11 of Set 2 | muli
# Processing Record 12 of Set 2 | upernavik
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | lebu
# Processing Record 15 of Set 2 | chuy
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | faya
# Processing Record 18 of Set 2 | ceara-mirim
# City not found. Skipping...
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | peleduy
# Processing Record 21 of Set 2 | moche
# Processing Record 22 of Set 2 | alice springs
# Processing Record 23 of Set 2 | jiroft
# City not found. Skipping...
# Processing Record 24 of Set 2 | anaconda
# Processing Record 25 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 2 | talnakh
# Processing Record 27 of Set 2 | bubaque
# Processing Record 28 of Set 2 | klaksvik
# Processing Record 29 of Set 2 | leningradskiy
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | saint-philippe
# Processing Record 32 of Set 2 | rosario
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | cooma
# Processing Record 35 of Set 2 | severodvinsk
# Processing Record 36 of Set 2 | yarmouth
# Processing Record 37 of Set 2 | lompoc
# Processing Record 38 of Set 2 | vallenar
# Processing Record 39 of Set 2 | muromtsevo
# Processing Record 40 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 41 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 2 | rio grande
# Processing Record 43 of Set 2 | ribeira grande
# Processing Record 44 of Set 2 | turtas
# Processing Record 45 of Set 2 | berezovyy
# Processing Record 46 of Set 2 | dunedin
# Processing Record 47 of Set 2 | atuona
# Processing Record 48 of Set 2 | acarau
# Processing Record 49 of Set 2 | sarangani
# Processing Record 50 of Set 2 | caravelas
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | bonnyville
# Processing Record 3 of Set 3 | marsa matruh
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | nowogard
# Processing Record 6 of Set 3 | muros
# Processing Record 7 of Set 3 | henties bay
# Processing Record 8 of Set 3 | jamestown
# Processing Record 9 of Set 3 | westport
# Processing Record 10 of Set 3 | half moon bay
# Processing Record 11 of Set 3 | palenque
# Processing Record 12 of Set 3 | barmer
# Processing Record 13 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 3 | monrovia
# Processing Record 15 of Set 3 | naze
# Processing Record 16 of Set 3 | guerrero negro
# Processing Record 17 of Set 3 | komsomolskiy
# Processing Record 18 of Set 3 | okato
# Processing Record 19 of Set 3 | mar del plata
# Processing Record 20 of Set 3 | sobolevo
# Processing Record 21 of Set 3 | carutapera
# Processing Record 22 of Set 3 | mount isa
# Processing Record 23 of Set 3 | necochea
# Processing Record 24 of Set 3 | butaritari
# Processing Record 25 of Set 3 | sao sebastiao
# Processing Record 26 of Set 3 | knysna
# Processing Record 27 of Set 3 | shenjiamen
# Processing Record 28 of Set 3 | east london
# Processing Record 29 of Set 3 | yerbogachen
# Processing Record 30 of Set 3 | egvekinot
# Processing Record 31 of Set 3 | kavaratti
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 3 | berlevag
# Processing Record 35 of Set 3 | port augusta
# Processing Record 36 of Set 3 | castro
# Processing Record 37 of Set 3 | baiyin
# Processing Record 38 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 3 | yumen
# Processing Record 40 of Set 3 | evanston
# Processing Record 41 of Set 3 | marinette
# Processing Record 42 of Set 3 | payo
# Processing Record 43 of Set 3 | baker city
# Processing Record 44 of Set 3 | lufilufi
# Processing Record 45 of Set 3 | laguna
# Processing Record 46 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 3 | port hedland
# Processing Record 48 of Set 3 | port hardy
# Processing Record 49 of Set 3 | tazovskiy
# Processing Record 50 of Set 3 | sao filipe
# Processing Record 1 of Set 4 | salalah
# Processing Record 2 of Set 4 | solnechnyy
# Processing Record 3 of Set 4 | meadow lake
# Processing Record 4 of Set 4 | trindade
# Processing Record 5 of Set 4 | ancud
# Processing Record 6 of Set 4 | san patricio
# Processing Record 7 of Set 4 | kodiak
# Processing Record 8 of Set 4 | barrow
# Processing Record 9 of Set 4 | longyearbyen
# Processing Record 10 of Set 4 | isangel
# Processing Record 11 of Set 4 | yulara
# Processing Record 12 of Set 4 | zyryanka
# Processing Record 13 of Set 4 | shkotovo-26
# City not found. Skipping...
# Processing Record 14 of Set 4 | husavik
# Processing Record 15 of Set 4 | galiakot
# Processing Record 16 of Set 4 | bandarbeyla
# Processing Record 17 of Set 4 | grindavik
# Processing Record 18 of Set 4 | dongli
# Processing Record 19 of Set 4 | griffith
# Processing Record 20 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 21 of Set 4 | pohrebyshche
# Processing Record 22 of Set 4 | agsu
# City not found. Skipping...
# Processing Record 23 of Set 4 | tuatapere
# Processing Record 24 of Set 4 | eyl
# Processing Record 25 of Set 4 | maniitsoq
# Processing Record 26 of Set 4 | brunswick
# Processing Record 27 of Set 4 | kembolcha
# Processing Record 28 of Set 4 | yangambi
# Processing Record 29 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 30 of Set 4 | luderitz
# Processing Record 31 of Set 4 | meulaboh
# Processing Record 32 of Set 4 | cabo san lucas
# Processing Record 33 of Set 4 | arraial do cabo
# Processing Record 34 of Set 4 | liverpool
# Processing Record 35 of Set 4 | dargaville
# Processing Record 36 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 4 | qaqortoq
# Processing Record 38 of Set 4 | norman wells
# Processing Record 39 of Set 4 | grajewo
# Processing Record 40 of Set 4 | cidreira
# Processing Record 41 of Set 4 | nouadhibou
# Processing Record 42 of Set 4 | chokurdakh
# Processing Record 43 of Set 4 | fukue
# Processing Record 44 of Set 4 | tuktoyaktuk
# Processing Record 45 of Set 4 | uvira
# Processing Record 46 of Set 4 | mbacke
# City not found. Skipping...
# Processing Record 47 of Set 4 | beringovskiy
# Processing Record 48 of Set 4 | mbanza-ngungu
# Processing Record 49 of Set 4 | uren
# Processing Record 50 of Set 4 | canarana
# Processing Record 1 of Set 5 | thompson
# Processing Record 2 of Set 5 | algarrobo
# Processing Record 3 of Set 5 | pizhanka
# Processing Record 4 of Set 5 | marienburg
# Processing Record 5 of Set 5 | masty
# Processing Record 6 of Set 5 | shalinskoye
# Processing Record 7 of Set 5 | maraa
# Processing Record 8 of Set 5 | natal
# Processing Record 9 of Set 5 | ambalavao
# Processing Record 10 of Set 5 | mahanoro
# Processing Record 11 of Set 5 | madimba
# Processing Record 12 of Set 5 | ahipara
# Processing Record 13 of Set 5 | resistencia
# Processing Record 14 of Set 5 | victoria
# Processing Record 15 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 5 | vryburg
# Processing Record 17 of Set 5 | hamilton
# Processing Record 18 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 5 | bellefontaine
# Processing Record 20 of Set 5 | abu jubayhah
# City not found. Skipping...
# Processing Record 21 of Set 5 | vao
# Processing Record 22 of Set 5 | vila franca do campo
# Processing Record 23 of Set 5 | jiuquan
# Processing Record 24 of Set 5 | kruisfontein
# Processing Record 25 of Set 5 | ostrovnoy
# Processing Record 26 of Set 5 | breda
# Processing Record 27 of Set 5 | port hawkesbury
# Processing Record 28 of Set 5 | yaan
# Processing Record 29 of Set 5 | leshukonskoye
# Processing Record 30 of Set 5 | nabire
# Processing Record 31 of Set 5 | kapiri mposhi
# Processing Record 32 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 33 of Set 5 | gerede
# Processing Record 34 of Set 5 | pandan
# Processing Record 35 of Set 5 | sola
# Processing Record 36 of Set 5 | portland
# Processing Record 37 of Set 5 | narsaq
# Processing Record 38 of Set 5 | bengkulu
# Processing Record 39 of Set 5 | iqaluit
# Processing Record 40 of Set 5 | saskylakh
# Processing Record 41 of Set 5 | torres
# Processing Record 42 of Set 5 | oktyabrskiy
# Processing Record 43 of Set 5 | fort-shevchenko
# Processing Record 44 of Set 5 | derzhavinsk
# Processing Record 45 of Set 5 | san giustino
# Processing Record 46 of Set 5 | port alfred
# Processing Record 47 of Set 5 | merauke
# Processing Record 48 of Set 5 | saint-augustin
# Processing Record 49 of Set 5 | luena
# Processing Record 50 of Set 5 | kahului
# Processing Record 1 of Set 6 | torbay
# Processing Record 2 of Set 6 | khani
# Processing Record 3 of Set 6 | praia
# Processing Record 4 of Set 6 | fortuna
# Processing Record 5 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 6 | saldanha
# Processing Record 7 of Set 6 | rocha
# Processing Record 8 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 6 | shetpe
# Processing Record 10 of Set 6 | kaitangata
# Processing Record 11 of Set 6 | padang
# Processing Record 12 of Set 6 | bousso
# Processing Record 13 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 14 of Set 6 | sorland
# Processing Record 15 of Set 6 | leh
# Processing Record 16 of Set 6 | parrita
# Processing Record 17 of Set 6 | asha
# Processing Record 18 of Set 6 | rivadavia
# Processing Record 19 of Set 6 | nome
# Processing Record 20 of Set 6 | omboue
# Processing Record 21 of Set 6 | port blair
# Processing Record 22 of Set 6 | codrington
# Processing Record 23 of Set 6 | nanortalik
# Processing Record 24 of Set 6 | yatou
# Processing Record 25 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 6 | touros
# Processing Record 27 of Set 6 | gat
# Processing Record 28 of Set 6 | santa cruz do rio pardo
# Processing Record 29 of Set 6 | ixtapa
# Processing Record 30 of Set 6 | mapastepec
# Processing Record 31 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 6 | saint george
# Processing Record 33 of Set 6 | madang
# Processing Record 34 of Set 6 | kapuskasing
# Processing Record 35 of Set 6 | lavumisa
# Processing Record 36 of Set 6 | praya
# Processing Record 37 of Set 6 | chifeng
# Processing Record 38 of Set 6 | karpathos
# Processing Record 39 of Set 6 | beloha
# Processing Record 40 of Set 6 | cap malheureux
# Processing Record 41 of Set 6 | tayoltita
# Processing Record 42 of Set 6 | kieta
# Processing Record 43 of Set 6 | mongo
# Processing Record 44 of Set 6 | los llanos de aridane
# Processing Record 45 of Set 6 | cantanhede
# Processing Record 46 of Set 6 | kutum
# Processing Record 47 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 6 | maroantsetra
# Processing Record 49 of Set 6 | vardo
# Processing Record 50 of Set 6 | kimberley
# Processing Record 1 of Set 7 | tecoanapa
# Processing Record 2 of Set 7 | severo-kurilsk
# Processing Record 3 of Set 7 | daru
# Processing Record 4 of Set 7 | hillsborough
# Processing Record 5 of Set 7 | naberera
# Processing Record 6 of Set 7 | limon
# Processing Record 7 of Set 7 | lakatoro
# Processing Record 8 of Set 7 | yanggu
# Processing Record 9 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 10 of Set 7 | wairoa
# Processing Record 11 of Set 7 | abha
# Processing Record 12 of Set 7 | hobyo
# Processing Record 13 of Set 7 | mount gambier
# Processing Record 14 of Set 7 | pevek
# Processing Record 15 of Set 7 | kushima
# Processing Record 16 of Set 7 | pouebo
# Processing Record 17 of Set 7 | tilichiki
# Processing Record 18 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 7 | kavieng
# Processing Record 20 of Set 7 | safaqis
# City not found. Skipping...
# Processing Record 21 of Set 7 | buluang
# Processing Record 22 of Set 7 | doha
# Processing Record 23 of Set 7 | sibolga
# Processing Record 24 of Set 7 | batticaloa
# Processing Record 25 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 7 | groa
# Processing Record 27 of Set 7 | port moresby
# Processing Record 28 of Set 7 | belmonte
# Processing Record 29 of Set 7 | constitucion
# Processing Record 30 of Set 7 | lazaro cardenas
# Processing Record 31 of Set 7 | qinhuangdao
# Processing Record 32 of Set 7 | virginia beach
# Processing Record 33 of Set 7 | clyde river
# Processing Record 34 of Set 7 | quatre cocos
# Processing Record 35 of Set 7 | ous
# Processing Record 36 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 7 | sakakah
# Processing Record 38 of Set 7 | souillac
# Processing Record 39 of Set 7 | imbituba
# Processing Record 40 of Set 7 | hami
# Processing Record 41 of Set 7 | uzhur
# Processing Record 42 of Set 7 | kishi
# Processing Record 43 of Set 7 | canto do buriti
# Processing Record 44 of Set 7 | udachnyy
# Processing Record 45 of Set 7 | hsichih
# City not found. Skipping...
# Processing Record 46 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 47 of Set 7 | ust-abakan
# Processing Record 48 of Set 7 | sanmenxia
# Processing Record 49 of Set 7 | sinaloa
# Processing Record 50 of Set 7 | tabriz
# Processing Record 1 of Set 8 | posse
# Processing Record 2 of Set 8 | walvis bay
# Processing Record 3 of Set 8 | shu
# Processing Record 4 of Set 8 | bambous virieux
# Processing Record 5 of Set 8 | baykit
# Processing Record 6 of Set 8 | vikhorevka
# Processing Record 7 of Set 8 | springfield
# Processing Record 8 of Set 8 | atambua
# Processing Record 9 of Set 8 | nieuw nickerie
# Processing Record 10 of Set 8 | aitape
# Processing Record 11 of Set 8 | teul
# City not found. Skipping...
# Processing Record 12 of Set 8 | crab hill
# City not found. Skipping...
# Processing Record 13 of Set 8 | conakry
# Processing Record 14 of Set 8 | soe
# Processing Record 15 of Set 8 | kristianstad
# Processing Record 16 of Set 8 | porbandar
# Processing Record 17 of Set 8 | shimoda
# Processing Record 18 of Set 8 | buin
# Processing Record 19 of Set 8 | presidencia roque saenz pena
# Processing Record 20 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 8 | mangaluru
# Processing Record 22 of Set 8 | taicheng
# Processing Record 23 of Set 8 | sao joao do piaui
# Processing Record 24 of Set 8 | santa cruz
# Processing Record 25 of Set 8 | chapais
# Processing Record 26 of Set 8 | hasaki
# Processing Record 27 of Set 8 | lagoa
# Processing Record 28 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 8 | veraval
# Processing Record 30 of Set 8 | itinga
# Processing Record 31 of Set 8 | cockburn town
# Processing Record 32 of Set 8 | urucara
# Processing Record 33 of Set 8 | inhambane
# Processing Record 34 of Set 8 | zemio
# Processing Record 35 of Set 8 | asfi
# Processing Record 36 of Set 8 | ornskoldsvik
# Processing Record 37 of Set 8 | cherskiy
# Processing Record 38 of Set 8 | ambilobe
# Processing Record 39 of Set 8 | luau
# Processing Record 40 of Set 8 | mabaruma
# Processing Record 41 of Set 8 | shar
# Processing Record 42 of Set 8 | humberto de campos
# Processing Record 43 of Set 8 | tecolutla
# Processing Record 44 of Set 8 | veliki preslav
# Processing Record 45 of Set 8 | ardmore
# Processing Record 46 of Set 8 | krasnoselkup
# Processing Record 47 of Set 8 | honningsvag
# Processing Record 48 of Set 8 | morgan city
# Processing Record 49 of Set 8 | ketchikan
# Processing Record 50 of Set 8 | tombouctou
# Processing Record 1 of Set 9 | kloulklubed
# Processing Record 2 of Set 9 | port macquarie
# Processing Record 3 of Set 9 | adrar
# Processing Record 4 of Set 9 | ypsonas
# Processing Record 5 of Set 9 | mogadishu
# Processing Record 6 of Set 9 | namibe
# Processing Record 7 of Set 9 | makarska
# Processing Record 8 of Set 9 | kamenka
# Processing Record 9 of Set 9 | chicama
# Processing Record 10 of Set 9 | batsfjord
# Processing Record 11 of Set 9 | pangnirtung
# Processing Record 12 of Set 9 | kiunga
# Processing Record 13 of Set 9 | fairbanks
# Processing Record 14 of Set 9 | college
# Processing Record 15 of Set 9 | buraydah
# Processing Record 16 of Set 9 | bud
# Processing Record 17 of Set 9 | gushikawa
# Processing Record 18 of Set 9 | rincon
# Processing Record 19 of Set 9 | iskateley
# Processing Record 20 of Set 9 | takoradi
# Processing Record 21 of Set 9 | anloga
# Processing Record 22 of Set 9 | big bend
# Processing Record 23 of Set 9 | nantucket
# Processing Record 24 of Set 9 | santa isabel do rio negro
# Processing Record 25 of Set 9 | slave lake
# Processing Record 26 of Set 9 | aden
# Processing Record 27 of Set 9 | tres arroyos
# Processing Record 28 of Set 9 | araguacu
# Processing Record 29 of Set 9 | gamba
# Processing Record 30 of Set 9 | paros
# Processing Record 31 of Set 9 | katangli
# Processing Record 32 of Set 9 | byron bay
# Processing Record 33 of Set 9 | cabedelo
# Processing Record 34 of Set 9 | acapulco
# Processing Record 35 of Set 9 | olafsvik
# Processing Record 36 of Set 9 | nelson bay
# Processing Record 37 of Set 9 | batagay-alyta
# Processing Record 38 of Set 9 | russkaya polyana
# Processing Record 39 of Set 9 | maldonado
# Processing Record 40 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 41 of Set 9 | kismayo
# Processing Record 42 of Set 9 | malinovskiy
# Processing Record 43 of Set 9 | richards bay
# Processing Record 44 of Set 9 | tabou
# Processing Record 45 of Set 9 | alofi
# Processing Record 46 of Set 9 | bada
# Processing Record 47 of Set 9 | lucea
# Processing Record 48 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 9 | zaton
# Processing Record 50 of Set 9 | muisne
# Processing Record 1 of Set 10 | sampit
# Processing Record 2 of Set 10 | keshan
# City not found. Skipping...
# Processing Record 3 of Set 10 | panzhihua
# Processing Record 4 of Set 10 | goundam
# Processing Record 5 of Set 10 | tulun
# Processing Record 6 of Set 10 | huejuquilla el alto
# Processing Record 7 of Set 10 | fairlie
# Processing Record 8 of Set 10 | baracoa
# Processing Record 9 of Set 10 | sayat
# Processing Record 10 of Set 10 | monte patria
# Processing Record 11 of Set 10 | umm lajj
# Processing Record 12 of Set 10 | wattegama
# Processing Record 13 of Set 10 | bursol
# City not found. Skipping...
# Processing Record 14 of Set 10 | brae
# Processing Record 15 of Set 10 | marawi
# Processing Record 16 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 17 of Set 10 | mahendragarh
# Processing Record 18 of Set 10 | cravo norte
# Processing Record 19 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 20 of Set 10 | maniwaki
# Processing Record 21 of Set 10 | bosaso
# Processing Record 22 of Set 10 | aras
# Processing Record 23 of Set 10 | ulladulla
# Processing Record 24 of Set 10 | acajutla
# Processing Record 25 of Set 10 | balkanabat
# Processing Record 26 of Set 10 | biak
# Processing Record 27 of Set 10 | vavuniya
# Processing Record 28 of Set 10 | dayong
# Processing Record 29 of Set 10 | comodoro rivadavia
# Processing Record 30 of Set 10 | vostok
# Processing Record 31 of Set 10 | vagur
# Processing Record 32 of Set 10 | kurchum
# Processing Record 33 of Set 10 | nyrob
# Processing Record 34 of Set 10 | canaries
# Processing Record 35 of Set 10 | banda aceh
# Processing Record 36 of Set 10 | gorodovikovsk
# Processing Record 37 of Set 10 | vieux-habitants
# Processing Record 38 of Set 10 | severnoye
# Processing Record 39 of Set 10 | kalutara
# Processing Record 40 of Set 10 | sistranda
# Processing Record 41 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 42 of Set 10 | jamkhed
# Processing Record 43 of Set 10 | greenwood
# Processing Record 44 of Set 10 | aksarayskiy
# Processing Record 45 of Set 10 | mount pleasant
# Processing Record 46 of Set 10 | la paz
# Processing Record 47 of Set 10 | burnie
# Processing Record 48 of Set 10 | awbari
# Processing Record 49 of Set 10 | amapa
# Processing Record 50 of Set 10 | asuncion
# Processing Record 1 of Set 11 | bemidji
# Processing Record 2 of Set 11 | santa vitoria do palmar
# Processing Record 3 of Set 11 | san isidro
# Processing Record 4 of Set 11 | bathsheba
# Processing Record 5 of Set 11 | shimsk
# Processing Record 6 of Set 11 | dongsheng
# Processing Record 7 of Set 11 | hurricane
# Processing Record 8 of Set 11 | coihaique
# Processing Record 9 of Set 11 | broken hill
# Processing Record 10 of Set 11 | waipawa
# Processing Record 11 of Set 11 | ossora
# Processing Record 12 of Set 11 | san cristobal
# Processing Record 13 of Set 11 | gorontalo
# Processing Record 14 of Set 11 | nishihara
# Processing Record 15 of Set 11 | rypefjord
# Processing Record 16 of Set 11 | xai-xai
# Processing Record 17 of Set 11 | nelidovo
# Processing Record 18 of Set 11 | male
# Processing Record 19 of Set 11 | whitehorse
# Processing Record 20 of Set 11 | vargem alta
# Processing Record 21 of Set 11 | mlonggo
# Processing Record 22 of Set 11 | lavrentiya
# Processing Record 23 of Set 11 | mansfield
# Processing Record 24 of Set 11 | nyalikungu
# Processing Record 25 of Set 11 | yenagoa
# Processing Record 26 of Set 11 | galesong
# Processing Record 27 of Set 11 | whitianga
# Processing Record 28 of Set 11 | baturyn
# Processing Record 29 of Set 11 | puerto berrio
# Processing Record 30 of Set 11 | provideniya
# Processing Record 31 of Set 11 | senanga
# Processing Record 32 of Set 11 | ahrensburg
# Processing Record 33 of Set 11 | coruripe
# Processing Record 34 of Set 11 | wagar
# Processing Record 35 of Set 11 | rapar
# Processing Record 36 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 37 of Set 11 | duku
# Processing Record 38 of Set 11 | bama
# Processing Record 39 of Set 11 | sao raimundo nonato
# Processing Record 40 of Set 11 | coahuayana
# Processing Record 41 of Set 11 | port lincoln
# Processing Record 42 of Set 11 | juifang
# City not found. Skipping...
# Processing Record 43 of Set 11 | korla
# Processing Record 44 of Set 11 | noumea
# Processing Record 45 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 46 of Set 11 | myski
# Processing Record 47 of Set 11 | santa fe
# Processing Record 48 of Set 11 | tazmalt
# Processing Record 49 of Set 11 | raudeberg
# Processing Record 50 of Set 11 | antsohihy
# Processing Record 1 of Set 12 | izumo
# Processing Record 2 of Set 12 | kawalu
# Processing Record 3 of Set 12 | haines junction
# Processing Record 4 of Set 12 | paamiut
# Processing Record 5 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 6 of Set 12 | puerto cabezas
# Processing Record 7 of Set 12 | hegang
# Processing Record 8 of Set 12 | odessa
# Processing Record 9 of Set 12 | iguai
# Processing Record 10 of Set 12 | da nang
# Processing Record 11 of Set 12 | tugdan
# Processing Record 12 of Set 12 | esmeraldas
# Processing Record 13 of Set 12 | hay river
# Processing Record 14 of Set 12 | buala
# Processing Record 15 of Set 12 | aporawan
# City not found. Skipping...
# Processing Record 16 of Set 12 | verkhoyansk
# Processing Record 17 of Set 12 | siero
# Processing Record 18 of Set 12 | manokwari
# Processing Record 19 of Set 12 | elesbao veloso
# Processing Record 20 of Set 12 | nieuw amsterdam
# Processing Record 21 of Set 12 | towada
# Processing Record 22 of Set 12 | la sarre
# Processing Record 23 of Set 12 | srednekolymsk
# Processing Record 24 of Set 12 | berdigestyakh
# Processing Record 25 of Set 12 | rio bravo
# Processing Record 26 of Set 12 | prado
# Processing Record 27 of Set 12 | reconquista
# Processing Record 28 of Set 12 | berbera
# Processing Record 29 of Set 12 | kalundborg
# Processing Record 30 of Set 12 | darnah
# Processing Record 31 of Set 12 | sayyan
# Processing Record 32 of Set 12 | gaeta
# Processing Record 33 of Set 12 | havre-saint-pierre
# Processing Record 34 of Set 12 | roald
# Processing Record 35 of Set 12 | estepa
# Processing Record 36 of Set 12 | svetlyy
# Processing Record 37 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 12 | arman
# Processing Record 39 of Set 12 | mayumba
# Processing Record 40 of Set 12 | potzu
# City not found. Skipping...
# Processing Record 41 of Set 12 | bulungu
# Processing Record 42 of Set 12 | namatanai
# Processing Record 43 of Set 12 | opobo
# City not found. Skipping...
# Processing Record 44 of Set 12 | santo tomas
# Processing Record 45 of Set 12 | astipalaia
# City not found. Skipping...
# Processing Record 46 of Set 12 | nhulunbuy
# Processing Record 47 of Set 12 | concepcion
# Processing Record 48 of Set 12 | challans
# Processing Record 49 of Set 12 | mapimi
# Processing Record 50 of Set 12 | clinton
# Processing Record 1 of Set 13 | kaliua
# Processing Record 2 of Set 13 | avera
# Processing Record 3 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 13 | kinanah
# City not found. Skipping...
# Processing Record 5 of Set 13 | mechetinskaya
# Processing Record 6 of Set 13 | marti
# Processing Record 7 of Set 13 | coihueco
# Processing Record 8 of Set 13 | saint-pierre
# Processing Record 9 of Set 13 | mabai
# Processing Record 10 of Set 13 | shingu
# Processing Record 11 of Set 13 | sinjar
# Processing Record 12 of Set 13 | suhbaatar
# Processing Record 13 of Set 13 | aksha
# Processing Record 14 of Set 13 | san lorenzo
# Processing Record 15 of Set 13 | katsuura
# Processing Record 16 of Set 13 | kazachinskoye
# Processing Record 17 of Set 13 | djambala
# Processing Record 18 of Set 13 | shaunavon
# Processing Record 19 of Set 13 | bulgan
# Processing Record 20 of Set 13 | russell
# Processing Record 21 of Set 13 | mardin
# Processing Record 22 of Set 13 | shubarkuduk
# Processing Record 23 of Set 13 | masindi
# Processing Record 24 of Set 13 | vila
# Processing Record 25 of Set 13 | humaita
# Processing Record 26 of Set 13 | saint anthony
# Processing Record 27 of Set 13 | thinadhoo
# Processing Record 28 of Set 13 | nardaran
# Processing Record 29 of Set 13 | nichinan
# Processing Record 30 of Set 13 | ye
# City not found. Skipping...
# Processing Record 31 of Set 13 | shache
# Processing Record 32 of Set 13 | tongliao
# Processing Record 33 of Set 13 | zhangjiakou
# Processing Record 34 of Set 13 | fort nelson
# Processing Record 35 of Set 13 | nicolas bravo
# Processing Record 36 of Set 13 | sinnar
# Processing Record 37 of Set 13 | karla
# Processing Record 38 of Set 13 | teofilo otoni
# Processing Record 39 of Set 13 | xuddur
# Processing Record 40 of Set 13 | pontecagnano
# Processing Record 41 of Set 13 | taubate
# Processing Record 42 of Set 13 | dukat
# Processing Record 43 of Set 13 | flinders
# Processing Record 44 of Set 13 | abu samrah
# Processing Record 45 of Set 13 | eureka
# Processing Record 46 of Set 13 | rio rancho
# Processing Record 47 of Set 13 | sangod
# Processing Record 48 of Set 13 | muravlenko
# Processing Record 49 of Set 13 | anadyr
# Processing Record 50 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 14 | vila velha
# Processing Record 2 of Set 14 | harnosand
# Processing Record 3 of Set 14 | bambanglipuro
# Processing Record 4 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 5 of Set 14 | nauta
# Processing Record 6 of Set 14 | fougamou
# Processing Record 7 of Set 14 | geraldton
# Processing Record 8 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 9 of Set 14 | morant bay
# Processing Record 10 of Set 14 | oskaloosa
# Processing Record 11 of Set 14 | jiexiu
# Processing Record 12 of Set 14 | san anselmo
# Processing Record 13 of Set 14 | manama
# Processing Record 14 of Set 14 | salantai
# Processing Record 15 of Set 14 | nakamura
# Processing Record 16 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 14 | pahrump
# Processing Record 18 of Set 14 | bressanone
# Processing Record 19 of Set 14 | bolobo
# Processing Record 20 of Set 14 | hammerfest
# Processing Record 21 of Set 14 | along
# Processing Record 22 of Set 14 | burica
# City not found. Skipping...
# Processing Record 23 of Set 14 | katherine
# Processing Record 24 of Set 14 | vakhrushev
# Processing Record 25 of Set 14 | sawtell
# Processing Record 26 of Set 14 | kamloops
# Processing Record 27 of Set 14 | angadanan
# Processing Record 28 of Set 14 | belluru
# Processing Record 29 of Set 14 | bhind
# Processing Record 30 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 31 of Set 14 | mahon
# Processing Record 32 of Set 14 | auch
# Processing Record 33 of Set 14 | pathein
# Processing Record 34 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 35 of Set 14 | palaiokhora
# City not found. Skipping...
# Processing Record 36 of Set 14 | kyaikkami
# Processing Record 37 of Set 14 | rio gallegos
# Processing Record 38 of Set 14 | opuwo
# Processing Record 39 of Set 14 | bay roberts
# Processing Record 40 of Set 14 | iralaya
# Processing Record 41 of Set 14 | taltal
# Processing Record 42 of Set 14 | oksfjord
# Processing Record 43 of Set 14 | peruibe
# Processing Record 44 of Set 14 | chara
# Processing Record 45 of Set 14 | otavi
# Processing Record 46 of Set 14 | bontang
# Processing Record 47 of Set 14 | sabang
# Processing Record 48 of Set 14 | margate
# Processing Record 49 of Set 14 | alunitdag
# City not found. Skipping...
# Processing Record 50 of Set 14 | ucluelet
# Processing Record 1 of Set 15 | malpe
# Processing Record 2 of Set 15 | kamaishi
# Processing Record 3 of Set 15 | bongor
# Processing Record 4 of Set 15 | halifax
# Processing Record 5 of Set 15 | abilene
# Processing Record 6 of Set 15 | norfolk
# Processing Record 7 of Set 15 | poum
# Processing Record 8 of Set 15 | beyneu
# Processing Record 9 of Set 15 | aykhal
# Processing Record 10 of Set 15 | garoua boulai
# Processing Record 11 of Set 15 | tooele
# Processing Record 12 of Set 15 | deputatskiy
# Processing Record 13 of Set 15 | mwene-ditu
# Processing Record 14 of Set 15 | olbia
# Processing Record 15 of Set 15 | diamantino
# Processing Record 16 of Set 15 | el sauzal
# Processing Record 17 of Set 15 | ilulissat
# Processing Record 18 of Set 15 | agva
# City not found. Skipping...
# Processing Record 19 of Set 15 | smoky lake
# Processing Record 20 of Set 15 | matiari
# Processing Record 21 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 22 of Set 15 | christchurch
# Processing Record 23 of Set 15 | country club hills
# Processing Record 24 of Set 15 | vestmannaeyjar
# Processing Record 25 of Set 15 | jinchengjiang
# City not found. Skipping...
# Processing Record 26 of Set 15 | jepelacio
# Processing Record 27 of Set 15 | sao joao dos patos
# Processing Record 28 of Set 15 | meilu
# City not found. Skipping...
# Processing Record 29 of Set 15 | morris
# Processing Record 30 of Set 15 | kununurra
# Processing Record 31 of Set 15 | naumburg
# Processing Record 32 of Set 15 | verkhnechusovskiye gorodki
# Processing Record 33 of Set 15 | bichura
# Processing Record 34 of Set 15 | nago
# Processing Record 35 of Set 15 | macaboboni
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print (city_condition)
# Out:
# overcast clouds

# %%
len(weather_data)
# Out:
# 659

# %%
weather_data_df = pd.DataFrame(weather_data)
weather_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Esperance      AU -33.8667  121.9000     55.24        79           5
# 1       Qaanaaq      GL  77.4840  -69.3632     39.97        68         100
# 2         Tiksi      RU  71.6872  128.8694     51.40        90          99
# 3     Mahebourg      MU -20.4081   57.7000     70.09        64          75
# 4         Airai      TL  -8.9266  125.4092     71.62        31          70
# 5      Khatanga      RU  71.9667  102.5000     57.88        63          49
# 6       Labuhan      ID  -6.8844  112.2051     77.97        69           4
# 7      Karratha      AU -20.7377  116.8463     74.30        39          78
# 8    Georgetown      MY   5.4112  100.3354     85.93        83          20
# 9  Punta Arenas      CL -53.1500  -70.9167     33.91        93           0
#
#    Wind Speed                 Date Current Description
# 0       20.42  2021-07-26 01:20:20           clear sky
# 1        0.65  2021-07-26 01:24:58     overcast clouds
# 2        5.91  2021-07-26 01:24:58          light rain
# 3       10.36  2021-07-26 01:24:58       broken clouds
# 4        2.98  2021-07-26 01:24:58       broken clouds
# 5        2.15  2021-07-26 01:24:59    scattered clouds
# 6        6.13  2021-07-26 01:24:59           clear sky
# 7        4.07  2021-07-26 01:24:59       broken clouds
# 8        1.01  2021-07-26 01:24:59                haze
# 9       16.11  2021-07-26 01:24:30           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_data_df.to_csv(output_data_file, index_label="City_ID")
